# %%
import pandas as pd
import re
import itertools
from collections import defaultdict

class ApprOXimate:
    def __init__(self, csv_file_path):
        self.load_chemical_data(csv_file_path)
    
    def load_chemical_data(self, csv_file_path):
        df = pd.read_csv(csv_file_path)
        self.list1 = defaultdict(list)
        self.list2 = {}
        
        for _, row in df.iterrows():
            element = row['Element']
            ox = int(row['Ox'])
            red = int(row['Red'])
            srp = float(row['SRP (V)'])
            self.list1[element].append((ox, red, srp))
        
        # Fixed oxidation states for common elements
        fixed_oxidation_states = {
            'O': -2, 'Na': 1
        }
        
        for element, ox in fixed_oxidation_states.items():
            self.list2[element] = ox
    
    def parse_formula(self, formula_input):
        pattern = r'([A-Z][a-z]*)(\d*\.?\d*/?\d*\.?\d*)'
        matches = re.findall(pattern, formula_input)
        formula = {}
        
        for element, quantity_str in matches:
            if element not in self.list1 and element not in self.list2:
                print(f'Warning: Element {element} not found in database')
                return None
            
            quantity = 1.0
            if quantity_str:
                if '/' in quantity_str:
                    numerator, denominator = quantity_str.split('/')
                    quantity = float(numerator) / float(denominator)
                else:
                    quantity = float(quantity_str)
            
            formula[element] = formula.get(element, 0) + quantity
        
        return formula

    def charge_balance(self, formula):
        local_list1 = defaultdict(list)
        for element, states in self.list1.items():
            local_list1[element] = states.copy()
        
        total_charge = 0
        previous_charge_with_delta = float('nan')
        element_with_final_lowest_srp = None
        final_delta_ox_max = 0
        final_charge_with_delta = 0
        element_quantity = 0
        final_ox = 0
        final_red = 0
        
        iteration_count = 0
        max_iterations = 100
        
        while True:
            iteration_count += 1
            if iteration_count > max_iterations:
                break
            
            sum_non_m = 0
            sum_m = 0
            
            for element, quantity in formula.items():
                if element in self.list2:
                    red = self.list2[element]
                    sum_non_m += quantity * red
                else:
                    data = next((x for x in local_list1[element] if x[1] > 0), None)
                    if data:
                        sum_m += quantity * data[1]
            
            total_charge = round(sum_non_m + sum_m, 5)
            
            # Find element with lowest SRP
            lowest_srp_element = None
            lowest_srp = float('inf')
            
            for element, quantity in formula.items():
                if element not in self.list2:
                    data = next((x for x in local_list1[element] if x[1] > 0), None)
                    if data and data[2] < lowest_srp:
                        lowest_srp = data[2]
                        lowest_srp_element = {
                            'element': element,
                            'quantity': quantity,
                            'data': data
                        }
            
            if not lowest_srp_element:
                break
            
            delta_ox_max = round((lowest_srp_element['data'][0] - lowest_srp_element['data'][1]) * lowest_srp_element['quantity'], 5)
            charge_with_delta = round(delta_ox_max + total_charge, 5)
            
            if charge_with_delta == previous_charge_with_delta:
                break
            
            previous_charge_with_delta = charge_with_delta
            
            if charge_with_delta < 0:
                total_charge += delta_ox_max
                updated_data = next((x for x in local_list1[lowest_srp_element['element']] 
                                  if x[1] == lowest_srp_element['data'][1]), None)
                if updated_data:
                    new_data = next((x for x in local_list1[lowest_srp_element['element']] 
                                   if x[1] == updated_data[0]), None)
                    if not new_data:
                        new_data = (updated_data[0], updated_data[0], float('inf'))
                    
                    local_list1[lowest_srp_element['element']] = [
                        x for x in local_list1[lowest_srp_element['element']] 
                        if x[1] != updated_data[1]
                    ]
                    local_list1[lowest_srp_element['element']].append(new_data)
            else:
                element_with_final_lowest_srp = lowest_srp_element['element']
                final_delta_ox_max = delta_ox_max
                final_charge_with_delta = charge_with_delta
                element_quantity = lowest_srp_element['quantity']
                final_ox = lowest_srp_element['data'][0]
                final_red = lowest_srp_element['data'][1]
                break
        
        # Calculate final charge
        final_charge = 0
        for element, quantity in formula.items():
            if element in self.list2:
                final_charge += quantity * self.list2[element]
            elif element != element_with_final_lowest_srp:
                final_data = next((x for x in local_list1[element] if x[1] > 0), None)
                if final_data:
                    final_charge += quantity * final_data[1]
        
        if element_with_final_lowest_srp and (final_charge_with_delta == 0 or final_charge_with_delta > 0):
            if final_delta_ox_max != 0:  # Only adjust if there's actually a difference in oxidation states
                adjusted_quant = round(element_quantity * (final_charge_with_delta / final_delta_ox_max), 5)
                remaining_quant = round(element_quantity - adjusted_quant, 5)
                
                if adjusted_quant > 0:
                    final_charge += adjusted_quant * final_red
                if remaining_quant > 0:
                    final_charge += remaining_quant * final_ox
            else:
                # If no difference in oxidation states, just use the original quantity
                final_charge += element_quantity * final_red
        
        final_charge = round(final_charge, 5)
        
        # Build result string
        result_parts = []
        
        # Add fixed elements first
        for element in sorted(formula.keys()):
            if element in self.list2:
                result_parts.append(f"{element}:{self.list2[element]}:{formula[element]}")
        
        # Add variable elements
        for element in sorted(formula.keys()):
            if element not in self.list2 and element != element_with_final_lowest_srp:
                final_data = next((x for x in local_list1[element] if x[1] > 0), None)
                if final_data:
                    result_parts.append(f"{element}:{final_data[1]}:{formula[element]}")
        
        # Handle element with lowest SRP
        if element_with_final_lowest_srp and (final_charge_with_delta == 0 or final_charge_with_delta > 0):
            if final_delta_ox_max != 0:
                adjusted_quant = round(element_quantity * (final_charge_with_delta / final_delta_ox_max), 5)
                remaining_quant = round(element_quantity - adjusted_quant, 5)
                
                if adjusted_quant > 0:
                    result_parts.append(f"{element_with_final_lowest_srp}:{final_red}:{adjusted_quant}")
                if remaining_quant > 0:
                    result_parts.append(f"{element_with_final_lowest_srp}:{final_ox}:{remaining_quant}")
            else:
                # If no difference in oxidation states, just show the original quantity
                result_parts.append(f"{element_with_final_lowest_srp}:{final_red}:{element_quantity}")
        
        result_parts.append(f"FinalChargeBalance:{final_charge}")
        
        return ";".join(result_parts)
    
true_outputs = pd.read_csv("Correct Outputs.csv")
test_cases = true_outputs['Chemical'].unique().tolist()

# Create analyzer
analyzer = ApprOXimate('all_elements_oxidation_states(in).csv')

for formula in test_cases:
    parsed = analyzer.parse_formula(formula)
    if parsed:
        result = analyzer.charge_balance(parsed)
        correct_row = true_outputs[true_outputs['Chemical'] == formula]
        
        result_parts = result.split(";")
        result_dict = {part.split(":")[0]: part for part in result_parts}
        correct_dict = {part.split(":")[0]: part for part in correct_row['Correct Output'].values[0].split(";")}
        
        final_charge_balance_result = float(result_dict['FinalChargeBalance'].split(':')[1])
        final_correct_charge_balance = float(correct_dict['FinalChargeBalance'].split(':')[1])
        
        total_difference = abs(final_charge_balance_result - final_correct_charge_balance)
        
        if total_difference > 0.01:
            print(f"Discrepancy found for {formula}: {total_difference}, {result}")
# Out:
# Discrepancy found for Na0.5Mn1/9Cu8/27Fe8/27Ni8/27O2: 0.441, Na:1:0.5;O:-2:2.0;Cu:2:0.2962962962962963;Fe:3:0.2962962962962963;Mn:3:0.1111111111111111;Ni:4:0.2962962962962963;FinalChargeBalance:-0.5

# %%
import ipywidgets as widgets
from IPython.display import display

# Create the text input widget
text_input = widgets.Text(
    value='',
    description='Type here:',
    disabled=False
)

# Create an HTML widget to show the status/output
status_output = widgets.HTML(value="The text will appear here after you type something. :)")

# Define the function to handle changes
def on_text_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        status_output.value = f"You entered: {change['new']}"

# Observe changes in the text input
text_input.observe(on_text_change, names='value')

# Display the widgets
display(text_input, status_output)
# Out:
# Text(value='', description='Type here:')
# HTML(value='The text will appear here after you type something. :)')

# %%
analyzer = ApprOXimate('all_elements_oxidation_states(in).csv')
# parsed = analyzer.parse_formula(formula)
# result = analyzer.charge_balance(parsed)

import ipywidgets as widgets
from IPython.display import display

# Sample function that processes the input
def process_text(input_text):
    text_output = ""
    
    parsed = analyzer.parse_formula(input_text)
    result = analyzer.charge_balance(parsed)
    result_parts = result.split(";")
    for item in result_parts:
        if item.startswith("FinalChargeBalance:"):
            final_charge, value = item.split(":")
            result_parts = [f"Final Charge Balance is {value}"] + result_parts[1:]
            text_output += f"Final Charge Balance is {value}"
        else:
            element, oxstate, quantity = item.split(":")
            result_parts = [f"Element: {element} Quantity: {quantity} Oxidation State: {oxstate}"] + result_parts[1:]  # Keep the first part intact
            text_output += f"Element: {element} Quantity: {quantity} Oxidation State: {oxstate}<br>"
            
        result = text_output
    return result

# Widgets
text_input = widgets.Text(
    value='',
    description='Type here:',
    disabled=False
)

button = widgets.Button(
    description='Calculate Oxidation States',
    button_style='info',  # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click to process text',
    icon='check',
    layout=widgets.Layout(width='250px', height='40px')
)

output_display = widgets.HTML(value="Result will appear here")

# Button click handler
def on_button_click(b):
    user_input = text_input.value
    result = process_text(user_input)
    output_display.value = result

# Attach handler to button
button.on_click(on_button_click)

# Layout
ui = widgets.VBox([text_input, button, output_display])
display(ui)
# Out:
# VBox(children=(Text(value='', description='Type here:'), Button(button_style='info', description='Calculate Ox…

# %%
import pandas as pd
import re
import itertools
from collections import defaultdict

class ApprOXimate:
    def __init__(self, csv_file_path):
        self.load_chemical_data(csv_file_path)
    
    def load_chemical_data(self, csv_file_path):
        df = pd.read_csv(csv_file_path)
        self.list1 = defaultdict(list)
        self.list2 = {}
        
        for _, row in df.iterrows():
            element = row['Element']
            ox = int(row['Ox'])
            red = int(row['Red'])
            srp = float(row['SRP (V)'])
            self.list1[element].append((ox, red, srp))
        
        # Fixed oxidation states for common elements
        fixed_oxidation_states = {
            'O': -2, 'Na': 1
        }
        
        for element, ox in fixed_oxidation_states.items():
            self.list2[element] = ox
    
    def parse_formula(self, formula_input):
        pattern = r'([A-Z][a-z]*)(\d*\.?\d*/?\d*\.?\d*)'
        matches = re.findall(pattern, formula_input)
        formula = {}
        
        for element, quantity_str in matches:
            if element not in self.list1 and element not in self.list2:
                print(f'Warning: Element {element} not found in database')
                return None
            
            quantity = 1.0
            if quantity_str:
                if '/' in quantity_str:
                    numerator, denominator = quantity_str.split('/')
                    quantity = float(numerator) / float(denominator)
                else:
                    quantity = float(quantity_str)
            
            formula[element] = formula.get(element, 0) + quantity
        
        return formula

    def charge_balance(self, formula):
        local_list1 = defaultdict(list)
        for element, states in self.list1.items():
            local_list1[element] = states.copy()
        
        total_charge = 0
        previous_charge_with_delta = float('nan')
        element_with_final_lowest_srp = None
        final_delta_ox_max = 0
        final_charge_with_delta = 0
        element_quantity = 0
        final_ox = 0
        final_red = 0
        
        iteration_count = 0
        max_iterations = 100
        
        while True:
            iteration_count += 1
            if iteration_count > max_iterations:
                break
            
            sum_non_m = 0
            sum_m = 0
            
            for element, quantity in formula.items():
                if element in self.list2:
                    red = self.list2[element]
                    sum_non_m += quantity * red
                else:
                    data = next((x for x in sorted(local_list1[element], key=lambda y: -y[1]) if x[1] > 0), None)
                    if data:
                        sum_m += quantity * data[1]
            
            total_charge = round(sum_non_m + sum_m, 5)
            
            # Find element with lowest SRP
            lowest_srp_element = None
            lowest_srp = float('inf')
            
            for element, quantity in formula.items():
                if element not in self.list2:
                    data = next((x for x in sorted(local_list1[element], key=lambda y: -y[1]) if x[1] > 0), None)
                    if data and data[2] < lowest_srp:
                        lowest_srp = data[2]
                        lowest_srp_element = {
                            'element': element,
                            'quantity': quantity,
                            'data': data
                        }
            
            if not lowest_srp_element:
                break
            
            delta_ox_max = round((lowest_srp_element['data'][0] - lowest_srp_element['data'][1]) * lowest_srp_element['quantity'], 5)
            charge_with_delta = round(delta_ox_max + total_charge, 5)
            
            if charge_with_delta == previous_charge_with_delta:
                break
            
            previous_charge_with_delta = charge_with_delta
            
            if charge_with_delta < 0:
                total_charge += delta_ox_max
                updated_data = next((x for x in local_list1[lowest_srp_element['element']] 
                                  if x[1] == lowest_srp_element['data'][1]), None)
                if updated_data:
                    new_data = next((x for x in local_list1[lowest_srp_element['element']] 
                                   if x[1] == updated_data[0]), None)
                    if not new_data:
                        new_data = (updated_data[0], updated_data[0], float('inf'))
                    
                    local_list1[lowest_srp_element['element']] = [
                        x for x in local_list1[lowest_srp_element['element']] 
                        if x[1] != updated_data[1]
                    ]
                    local_list1[lowest_srp_element['element']].append(new_data)
            else:
                element_with_final_lowest_srp = lowest_srp_element['element']
                final_delta_ox_max = delta_ox_max
                final_charge_with_delta = charge_with_delta
                element_quantity = lowest_srp_element['quantity']
                final_ox = lowest_srp_element['data'][0]
                final_red = lowest_srp_element['data'][1]
                break
        
        # Calculate final charge
        final_charge = 0
        for element, quantity in formula.items():
            if element in self.list2:
                final_charge += quantity * self.list2[element]
            elif element != element_with_final_lowest_srp:
                final_data = next((x for x in local_list1[element] if x[1] > 0), None)
                if final_data:
                    final_charge += quantity * final_data[1]
        
        if element_with_final_lowest_srp and (final_charge_with_delta == 0 or final_charge_with_delta > 0):
            if final_delta_ox_max != 0:  # Only adjust if there's actually a difference in oxidation states
                adjusted_quant = round(element_quantity * (final_charge_with_delta / final_delta_ox_max), 5)
                remaining_quant = round(element_quantity - adjusted_quant, 5)
                
                if adjusted_quant > 0:
                    final_charge += adjusted_quant * final_red
                if remaining_quant > 0:
                    final_charge += remaining_quant * final_ox
            else:
                # If no difference in oxidation states, just use the original quantity
                final_charge += element_quantity * final_red
        
        final_charge = round(final_charge, 5)
        
        # Build result string
        result_parts = []
        
        # Add fixed elements first
        for element in sorted(formula.keys()):
            if element in self.list2:
                result_parts.append(f"{element}:{self.list2[element]}:{formula[element]}")
        
        # Add variable elements
        for element in sorted(formula.keys()):
            if element not in self.list2 and element != element_with_final_lowest_srp:
                final_data = next((x for x in local_list1[element] if x[1] > 0), None)
                if final_data:
                    result_parts.append(f"{element}:{final_data[1]}:{formula[element]}")
        
        # Handle element with lowest SRP
        if element_with_final_lowest_srp and (final_charge_with_delta == 0 or final_charge_with_delta > 0):
            if final_delta_ox_max != 0:
                adjusted_quant = round(element_quantity * (final_charge_with_delta / final_delta_ox_max), 5)
                remaining_quant = round(element_quantity - adjusted_quant, 5)
                
                if adjusted_quant > 0:
                    result_parts.append(f"{element_with_final_lowest_srp}:{final_red}:{adjusted_quant}")
                if remaining_quant > 0:
                    result_parts.append(f"{element_with_final_lowest_srp}:{final_ox}:{remaining_quant}")
            else:
                # If no difference in oxidation states, just show the original quantity
                result_parts.append(f"{element_with_final_lowest_srp}:{final_red}:{element_quantity}")
        
        result_parts.append(f"FinalChargeBalance:{final_charge}")
        
        return ";".join(result_parts)
    
true_outputs = pd.read_csv("Correct Outputs.csv")
test_cases = true_outputs['Chemical'].unique().tolist()

# Create analyzer
analyzer = ApprOXimate('all_elements_oxidation_states(in).csv')

for formula in test_cases:
    parsed = analyzer.parse_formula(formula)
    if parsed:
        result = analyzer.charge_balance(parsed)
        correct_row = true_outputs[true_outputs['Chemical'] == formula]
        
        result_parts = result.split(";")
        result_dict = {part.split(":")[0]: part for part in result_parts}
        correct_dict = {part.split(":")[0]: part for part in correct_row['Correct Output'].values[0].split(";")}
        
        final_charge_balance_result = float(result_dict['FinalChargeBalance'].split(':')[1])
        final_correct_charge_balance = float(correct_dict['FinalChargeBalance'].split(':')[1])
        
        total_difference = abs(final_charge_balance_result - final_correct_charge_balance)
        
        if total_difference > 0.01:
            print(f"Discrepancy found for {formula}: {total_difference}, {result}")
# Out:
# Discrepancy found for NaMnO2: 2.33332, Na:1:1.0;O:-2:2.0;Mn:4:1.33333;FinalChargeBalance:2.33332
# Discrepancy found for NaCu0.5Fe0.5O2: 1.0, Na:1:1.0;O:-2:2.0;Cu:2:0.5;Fe:1:0.5;FinalChargeBalance:-1.5
# Discrepancy found for NaCu0.5Mn0.5O2: 0.5, Na:1:1.0;O:-2:2.0;Mn:3:0.5;Cu:2:0.5;FinalChargeBalance:-0.5
# Discrepancy found for NaFe0.5Mn0.5O2: 0.5, Na:1:1.0;O:-2:2.0;Mn:3:0.5;Fe:2:0.5;FinalChargeBalance:-0.5
# Discrepancy found for NaFe0.5Ni0.5O2: 0.5, Na:1:1.0;O:-2:2.0;Fe:1:0.5;Ni:4:0.5;FinalChargeBalance:-0.5
# Discrepancy found for NaMn0.5Ni0.5O2: 0.5, Na:1:1.0;O:-2:2.0;Mn:3:0.5;Ni:2:0.5;FinalChargeBalance:-0.5
# Discrepancy found for NaCu1/3Fe1/3Mn1/3O2: 0.33334, Na:1:1.0;O:-2:2.0;Cu:2:0.3333333333333333;Mn:3:0.3333333333333333;Fe:3:0.33333;FinalChargeBalance:-0.33334
# Discrepancy found for NaCu1/3Mn1/3Ni1/3O2: 0.33335, Na:1:1.0;O:-2:2.0;Cu:1:0.3333333333333333;Mn:3:0.3333333333333333;Ni:4:0.33333;FinalChargeBalance:-0.33335
# Discrepancy found for NaFe1/3Mn1/3Ni1/3O2: 0.66669, Na:1:1.0;O:-2:2.0;Fe:1:0.3333333333333333;Mn:3:0.3333333333333333;Ni:2:0.16667;Ni:4:0.16666;FinalChargeBalance:-0.66669
# Discrepancy found for NaCu0.25Fe0.25Mn0.25Ni0.25O2: 0.5, Na:1:1.0;O:-2:2.0;Fe:1:0.25;Mn:3:0.25;Ni:4:0.25;Cu:2:0.25;FinalChargeBalance:-0.5
# Discrepancy found for Na0.75FeO2: 2.0, Na:1:0.75;O:-2:2.0;Fe:1:1.0;FinalChargeBalance:-2.25
# Discrepancy found for Na0.75MnO2: 1.75, Na:1:0.75;O:-2:2.0;Mn:4:1.25;FinalChargeBalance:1.75
# Discrepancy found for Na0.75Cu0.5Fe0.5O2: 1.0, Na:1:0.75;O:-2:2.0;Cu:2:0.5;Fe:1:0.5;FinalChargeBalance:-1.75
# Discrepancy found for Na0.75Fe0.5Mn0.5O2: 0.5, Na:1:0.75;O:-2:2.0;Mn:3:0.5;Fe:2:0.25;Fe:3:0.25;FinalChargeBalance:-0.5
# Discrepancy found for Na0.75Mn0.5Ni0.5O2: 0.5, Na:1:0.75;O:-2:2.0;Mn:3:0.5;Ni:2:0.375;Ni:4:0.125;FinalChargeBalance:-0.5
# Discrepancy found for Na0.75Cu0.3Fe0.3Mn0.3O2: 0.59901, Na:1:0.75;O:-2:2.0;Cu:2:0.3;Fe:1:0.3;Mn:4:0.11667;Mn:7:0.18333;FinalChargeBalance:-0.60001
# Discrepancy found for Na0.75Cu0.3Fe0.3Ni0.3O2: 0.5999999999999999, Na:1:0.75;O:-2:2.0;Cu:2:0.3;Fe:1:0.3;Ni:4:0.3;FinalChargeBalance:-1.15
# Discrepancy found for Na0.75Fe0.3Mn0.3Ni0.3O2: 0.3, Na:1:0.75;O:-2:2.0;Mn:3:0.3;Ni:4:0.3;Fe:2:0.05;Fe:3:0.25;FinalChargeBalance:-0.3
# Discrepancy found for Na0.75Cu0.25Fe0.25Mn0.25Ni0.25O2: 0.25, Na:1:0.75;O:-2:2.0;Cu:2:0.25;Mn:3:0.25;Ni:4:0.25;Fe:3:0.25;FinalChargeBalance:-0.25
# Discrepancy found for Na0.5FeO2: 2.0, Na:1:0.5;O:-2:2.0;Fe:1:1.0;FinalChargeBalance:-2.5
# Discrepancy found for Na0.5MnO2: 1.16668, Na:1:0.5;O:-2:2.0;Mn:4:1.16667;FinalChargeBalance:1.16668
# Discrepancy found for Na0.5Cu0.5Fe0.5O2: 1.0, Na:1:0.5;O:-2:2.0;Cu:2:0.5;Fe:1:0.5;FinalChargeBalance:-2.0
# Discrepancy found for Na0.5Fe0.5Mn0.5O2: 0.5, Na:1:0.5;O:-2:2.0;Mn:3:0.5;Fe:3:0.5;FinalChargeBalance:-0.5
# Discrepancy found for Na0.5Mn0.5Ni0.5O2: 0.5, Na:1:0.5;O:-2:2.0;Mn:3:0.5;Ni:2:0.25;Ni:4:0.25;FinalChargeBalance:-0.5
# Discrepancy found for Na0.5Cu1/3Fe1/3Mn1/3O2: 0.6677, Na:1:0.5;O:-2:2.0;Cu:2:0.3333333333333333;Fe:1:0.3333333333333333;Mn:4:0.16667;Mn:7:0.16666;FinalChargeBalance:-0.6667
# Discrepancy found for Na0.5Cu1/3Fe1/3Ni1/3O2: 0.6636700000000001, Na:1:0.5;O:-2:2.0;Cu:2:0.3333333333333333;Fe:1:0.3333333333333333;Ni:4:0.3333333333333333;FinalChargeBalance:-1.16667
# Discrepancy found for Na0.5Fe1/3Mn1/3Ni1/3O2: 0.33334, Na:1:0.5;O:-2:2.0;Mn:3:0.3333333333333333;Ni:4:0.3333333333333333;Fe:2:0.16666;Fe:3:0.16667;FinalChargeBalance:-0.33334
# Discrepancy found for Na0.5Cu0.25Fe0.25Mn0.25Ni0.25O2: 0.49900999999999995, Na:1:0.5;O:-2:2.0;Cu:2:0.25;Fe:1:0.25;Ni:4:0.25;Mn:4:0.16667;Mn:7:0.08333;FinalChargeBalance:-0.50001
# Discrepancy found for Na0.75Cu1/3Fe1/3Mn1/3O2: 0.66569, Na:1:0.75;O:-2:2.0;Cu:2:0.3333333333333333;Fe:1:0.3333333333333333;Mn:4:0.25;Mn:7:0.08333;FinalChargeBalance:-0.66669
# Discrepancy found for Na0.75Cu1/3Fe1/3Ni1/3O2: 0.66367, Na:1:0.75;O:-2:2.0;Cu:2:0.3333333333333333;Fe:1:0.3333333333333333;Ni:4:0.3333333333333333;FinalChargeBalance:-0.91667
# Discrepancy found for Na0.75Cu1/3Mn1/3Ni1/3O2: 0.33334, Na:1:0.75;O:-2:2.0;Mn:3:0.3333333333333333;Ni:4:0.3333333333333333;Cu:1:0.08333;Cu:2:0.25;FinalChargeBalance:-0.33334
# Discrepancy found for Na0.75Fe1/3Mn1/3Ni1/3O2: 0.66669, Na:1:0.75;O:-2:2.0;Fe:1:0.3333333333333333;Mn:3:0.3333333333333333;Ni:2:0.04167;Ni:4:0.29166;FinalChargeBalance:-0.66669
# Discrepancy found for Na0.5Cu0.3Fe0.3Mn0.3O2: 0.60099, Na:1:0.5;O:-2:2.0;Cu:2:0.3;Fe:1:0.3;Mn:4:0.03333;Mn:7:0.26667;FinalChargeBalance:-0.59999
# Discrepancy found for Na0.5Cu0.3Fe0.3Ni0.3O2: 0.5999999999999999, Na:1:0.5;O:-2:2.0;Cu:2:0.3;Fe:1:0.3;Ni:4:0.3;FinalChargeBalance:-1.4
# Discrepancy found for Na0.5Fe0.3Mn0.3Ni0.3O2: 0.60099, Na:1:0.5;O:-2:2.0;Fe:1:0.3;Ni:4:0.3;Mn:4:0.23333;Mn:7:0.06667;FinalChargeBalance:-0.59999
# Discrepancy found for Na0.75Cu1/3Fe1.3Ni0.3O2: 0.73333, Na:1:0.75;O:-2:2.0;Cu:1:0.3333333333333333;Fe:1:1.3;Ni:2:0.44167;FinalChargeBalance:-0.73333
# Discrepancy found for NaMn2/3Cu1/6Fe1/6O2: 0.5, Na:1:1.0;O:-2:2.0;Fe:1:0.16666666666666666;Mn:3:0.6666666666666666;Cu:1:0.33333;FinalChargeBalance:-0.5
# Discrepancy found for NaNi2/3Fe1/6Cu1/6O2: 0.16765, Na:1:1.0;O:-2:2.0;Cu:1:0.16666666666666666;Fe:1:0.16666666666666666;Ni:2:0.08333;Ni:4:0.58334;FinalChargeBalance:-0.16665
# Discrepancy found for NaMn2/3Ni1/6Cu1/6O2: 0.33333, Na:1:1.0;O:-2:2.0;Cu:1:0.16666666666666666;Mn:3:0.6666666666666666;Ni:2:0.25;FinalChargeBalance:-0.33333
# Discrepancy found for NaMn2/3Fe1/6Ni1/6O2: 0.16567, Na:1:1.0;O:-2:2.0;Fe:1:0.16666666666666666;Mn:3:0.6666666666666666;Ni:2:0.33333;FinalChargeBalance:-0.16667
# Discrepancy found for NaFe2/3Cu1/6Mn1/6O2: 0.16666, Na:1:1.0;O:-2:2.0;Cu:2:0.16666666666666666;Mn:3:0.16666666666666666;Fe:3:0.66667;FinalChargeBalance:-0.16666
# Discrepancy found for NaNi2/3Cu1/6Mn1/6O2: 0.16665, Na:1:1.0;O:-2:2.0;Cu:1:0.16666666666666666;Mn:3:0.16666666666666666;Ni:2:0.25;Ni:4:0.41667;FinalChargeBalance:-0.16665
# Discrepancy found for NaFe2/3Ni1/6Mn1/6O2: 0.16666, Na:1:1.0;O:-2:2.0;Mn:3:0.16666666666666666;Ni:4:0.16666666666666666;Fe:2:0.33334;Fe:3:0.33333;FinalChargeBalance:-0.16666
# Discrepancy found for NaCu2/3Fe1/6Ni1/6O2: 0.33633, Na:1:1.0;O:-2:2.0;Cu:2:0.6666666666666666;Fe:1:0.16666666666666666;Ni:4:0.16666666666666666;FinalChargeBalance:-0.83333
# Discrepancy found for NaCu2/3Ni1/6Fe1/6O2: 0.33633, Na:1:1.0;O:-2:2.0;Cu:2:0.6666666666666666;Fe:1:0.16666666666666666;Ni:4:0.16666666666666666;FinalChargeBalance:-0.83333
# Discrepancy found for NaNi2/3Fe1/6Mn1/6O2: 0.33231, Na:1:1.0;O:-2:2.0;Fe:1:0.16666666666666666;Mn:3:0.16666666666666666;Ni:2:0.33333;Ni:4:0.33334;FinalChargeBalance:-0.33331
# Discrepancy found for NaCu2/3Ni1/9Mn1/9Fe1/9O2: 0.22177999999999998, Na:1:1.0;O:-2:2.0;Cu:2:0.6666666666666666;Fe:1:0.1111111111111111;Mn:3:0.1111111111111111;Ni:4:0.1111111111111111;FinalChargeBalance:-0.77778
# Discrepancy found for NaFe2/3Cu1/9Mn1/9Ni1/9O2: 0.1111, Na:1:1.0;O:-2:2.0;Cu:2:0.1111111111111111;Mn:3:0.1111111111111111;Ni:4:0.1111111111111111;Fe:2:0.11111;Fe:3:0.55556;FinalChargeBalance:-0.1111
# Discrepancy found for NaNi2/3Fe1/9Cu1/9Mn1/9O2: 0.2222, Na:1:1.0;O:-2:2.0;Cu:1:0.1111111111111111;Fe:1:0.1111111111111111;Mn:3:0.1111111111111111;Ni:2:0.22222;Ni:4:0.44445;FinalChargeBalance:-0.2222
# Discrepancy found for NaMn2/3Cu1/9Fe1/9Ni1/9O2: 0.33334, Na:1:1.0;O:-2:2.0;Cu:1:0.1111111111111111;Fe:1:0.1111111111111111;Mn:3:0.6666666666666666;Ni:2:0.22222;FinalChargeBalance:-0.33334
# Discrepancy found for NaMn1/9Cu8/27Fe8/27Ni8/27O2: 0.1111, Na:1:1.0;O:-2:2.0;Cu:2:0.2962962962962963;Mn:3:0.1111111111111111;Ni:4:0.2962962962962963;Fe:2:0.11111;Fe:3:0.18519;FinalChargeBalance:-0.1111
# Discrepancy found for NaNi1/9Cu8/27Fe8/27Mn8/27O2: 0.29628, Na:1:1.0;O:-2:2.0;Cu:2:0.2962962962962963;Mn:3:0.2962962962962963;Ni:4:0.1111111111111111;Fe:2:0.11111;Fe:3:0.18519;FinalChargeBalance:-0.29628
# Discrepancy found for NaFe1/9Mn8/27Cu8/27Ni8/27O2: 0.4074, Na:1:1.0;O:-2:2.0;Fe:1:0.1111111111111111;Mn:3:0.2962962962962963;Ni:4:0.2962962962962963;Cu:1:0.18519;Cu:2:0.11111;FinalChargeBalance:-0.4074
# Discrepancy found for NaCu1/9Mn8/27Fe8/27Ni8/27O2: 0.59258, Na:1:1.0;O:-2:2.0;Cu:1:0.1111111111111111;Fe:1:0.2962962962962963;Mn:3:0.2962962962962963;Ni:2:0.03704;Ni:4:0.25926;FinalChargeBalance:-0.59258
# Discrepancy found for NaFe7/18Ni7/18Cu1/9Mn1/9O2: 0.5, Na:1:1.0;O:-2:2.0;Fe:1:0.3888888888888889;Mn:3:0.1111111111111111;Ni:4:0.3888888888888889;Cu:2:0.11111;FinalChargeBalance:-0.5
# Discrepancy found for NaCu2/18Ni7/18Fe1/9Mn1/9O2: 0.22177999999999998, Na:1:1.0;O:-2:2.0;Cu:2:0.1111111111111111;Fe:1:0.1111111111111111;Mn:3:0.1111111111111111;Ni:4:0.3888888888888889;FinalChargeBalance:-0.77778
# Discrepancy found for NaFe7/18Mn7/18Cu1/9Ni1/9O2: 0.77778, Na:1:1.0;O:-2:2.0;Fe:1:0.3888888888888889;Mn:3:0.3888888888888889;Ni:4:0.1111111111111111;Cu:2:0.11111;FinalChargeBalance:-0.77778
# Discrepancy found for NaCu7/18Fe7/18Mn1/9Ni1/9O2: 0.77877, Na:1:1.0;O:-2:2.0;Cu:2:0.3888888888888889;Fe:1:0.3888888888888889;Ni:4:0.1111111111111111;Mn:4:0.05555;Mn:7:0.05556;FinalChargeBalance:-0.77777
# Discrepancy found for NaMn7/18Ni7/18Fe1/9Cu1/9O2: 0.49999, Na:1:1.0;O:-2:2.0;Cu:1:0.1111111111111111;Fe:1:0.1111111111111111;Mn:3:0.3888888888888889;Ni:2:0.22222;Ni:4:0.16667;FinalChargeBalance:-0.49999
# Discrepancy found for NaCu7/18Mn7/18Fe1/9Ni1/9O2: 0.5, Na:1:1.0;O:-2:2.0;Fe:1:0.1111111111111111;Mn:3:0.3888888888888889;Ni:4:0.1111111111111111;Cu:2:0.38889;FinalChargeBalance:-0.5
# Discrepancy found for Na0.75Mn2/3Cu1/6Fe1/6O2: 0.83333, Na:1:0.75;O:-2:2.0;Fe:1:0.16666666666666666;Mn:3:0.6666666666666666;Cu:1:0.08334;Cu:2:0.08333;FinalChargeBalance:-0.83333
# Discrepancy found for Na0.75Ni2/3Fe1/6Cu1/6O2: 0.16667, Na:1:0.75;O:-2:2.0;Fe:1:0.16666666666666666;Ni:4:0.6666666666666666;Cu:1:0.08334;Cu:2:0.08333;FinalChargeBalance:-0.16667
# Discrepancy found for Na0.75Mn2/3Ni1/6Cu1/6O2: 0.66665, Na:1:0.75;O:-2:2.0;Cu:1:0.16666666666666666;Mn:3:0.6666666666666666;Ni:2:0.125;Ni:4:0.04167;FinalChargeBalance:-0.66665
# Discrepancy found for Na0.75Mn2/3Fe1/6Ni1/6O2: 0.66667, Na:1:0.75;O:-2:2.0;Fe:1:0.16666666666666666;Mn:3:0.6666666666666666;Ni:2:0.20833;FinalChargeBalance:-0.66667
# Discrepancy found for Na0.75Fe2/3Cu1/6Mn1/6O2: 1.3323, Na:1:0.75;O:-2:2.0;Cu:2:0.16666666666666666;Fe:1:0.6666666666666666;Mn:4:0.08333;Mn:7:0.08334;FinalChargeBalance:-1.3333
# Discrepancy found for Na0.75Fe2/3Cu1/6Ni1/6O2: 1.3363299999999998, Na:1:0.75;O:-2:2.0;Cu:2:0.16666666666666666;Fe:1:0.6666666666666666;Ni:4:0.16666666666666666;FinalChargeBalance:-1.58333
# Discrepancy found for Na0.75Ni2/3Cu1/6Mn1/6O2: 0.16665, Na:1:0.75;O:-2:2.0;Cu:1:0.16666666666666666;Mn:3:0.16666666666666666;Ni:2:0.125;Ni:4:0.54167;FinalChargeBalance:-0.16665
# Discrepancy found for Na0.75Fe2/3Ni1/6Mn1/6O2: 0.16666, Na:1:0.75;O:-2:2.0;Mn:3:0.16666666666666666;Ni:4:0.16666666666666666;Fe:2:0.08334;Fe:3:0.58333;FinalChargeBalance:-0.16666
# Discrepancy found for Na0.75Cu2/3Fe1/6Ni1/6O2: 0.3363299999999999, Na:1:0.75;O:-2:2.0;Cu:2:0.6666666666666666;Fe:1:0.16666666666666666;Ni:4:0.16666666666666666;FinalChargeBalance:-1.08333
# Discrepancy found for Na0.75Cu2/3Ni1/6Fe1/6O2: 0.3363299999999999, Na:1:0.75;O:-2:2.0;Cu:2:0.6666666666666666;Fe:1:0.16666666666666666;Ni:4:0.16666666666666666;FinalChargeBalance:-1.08333
# Discrepancy found for Na0.75Ni2/3Fe1/6Mn1/6O2: 0.33431, Na:1:0.75;O:-2:2.0;Fe:1:0.16666666666666666;Mn:3:0.16666666666666666;Ni:2:0.20833;Ni:4:0.45834;FinalChargeBalance:-0.33331
# Discrepancy found for Na0.75Cu2/3Ni1/9Mn1/9Fe1/9O2: 0.22177999999999987, Na:1:0.75;O:-2:2.0;Cu:2:0.6666666666666666;Fe:1:0.1111111111111111;Mn:3:0.1111111111111111;Ni:4:0.1111111111111111;FinalChargeBalance:-1.02778
# Discrepancy found for Na0.75Fe2/3Cu1/9Mn1/9Ni1/9O2: 1.33233, Na:1:0.75;O:-2:2.0;Cu:2:0.1111111111111111;Fe:1:0.6666666666666666;Ni:4:0.1111111111111111;Mn:4:0.06481;Mn:7:0.0463;FinalChargeBalance:-1.33333
# Discrepancy found for Na0.75Ni2/3Fe1/9Cu1/9Mn1/9O2: 0.2222, Na:1:0.75;O:-2:2.0;Cu:1:0.1111111111111111;Fe:1:0.1111111111111111;Mn:3:0.1111111111111111;Ni:2:0.09722;Ni:4:0.56945;FinalChargeBalance:-0.2222
# Discrepancy found for Na0.75Mn2/3Cu1/9Fe1/9Ni1/9O2: 0.77778, Na:1:0.75;O:-2:2.0;Cu:1:0.1111111111111111;Fe:1:0.1111111111111111;Mn:3:0.6666666666666666;Ni:2:0.09722;Ni:4:0.01389;FinalChargeBalance:-0.77778
# Discrepancy found for Na0.75Mn1/9Cu8/27Fe8/27Ni8/27O2: 0.59159, Na:1:0.75;O:-2:2.0;Cu:2:0.2962962962962963;Fe:1:0.2962962962962963;Ni:4:0.2962962962962963;Mn:4:0.06481;Mn:7:0.0463;FinalChargeBalance:-0.59259
# Discrepancy found for Na0.75Ni1/9Cu8/27Fe8/27Mn8/27O2: 0.59157, Na:1:0.75;O:-2:2.0;Cu:2:0.2962962962962963;Fe:1:0.2962962962962963;Ni:4:0.1111111111111111;Mn:4:0.25;Mn:7:0.0463;FinalChargeBalance:-0.59257
# Discrepancy found for Na0.75Fe1/9Mn8/27Cu8/27Ni8/27O2: 0.2963, Na:1:0.75;O:-2:2.0;Cu:2:0.2962962962962963;Mn:3:0.2962962962962963;Ni:4:0.2962962962962963;Fe:2:0.0463;Fe:3:0.06481;FinalChargeBalance:-0.2963
# Discrepancy found for Na0.75Cu1/9Mn8/27Fe8/27Ni8/27O2: 0.29629, Na:1:0.75;O:-2:2.0;Cu:2:0.1111111111111111;Mn:3:0.2962962962962963;Ni:4:0.2962962962962963;Fe:2:0.23149;Fe:3:0.06481;FinalChargeBalance:-0.29629
# Discrepancy found for Na0.75Fe7/18Ni7/18Cu1/9Mn1/9O2: 0.11111, Na:1:0.75;O:-2:2.0;Cu:2:0.1111111111111111;Mn:3:0.1111111111111111;Ni:4:0.3888888888888889;Fe:2:0.13889;Fe:3:0.25;FinalChargeBalance:-0.11111
# Discrepancy found for Na0.75Cu7/18Ni7/18Fe1/9Mn1/9O2: 0.22122, Na:1:0.75;O:-2:2.0;Cu:2:0.3888888888888889;Fe:1:0.1111111111111111;Ni:4:0.3888888888888889;Mn:4:0.06481;Mn:7:0.0463;FinalChargeBalance:-0.22222
# Discrepancy found for Na0.75Fe7/18Mn7/18Cu1/9Ni1/9O2: 0.38889, Na:1:0.75;O:-2:2.0;Cu:2:0.1111111111111111;Mn:3:0.3888888888888889;Ni:4:0.1111111111111111;Fe:2:0.13889;Fe:3:0.25;FinalChargeBalance:-0.38889
# Discrepancy found for Na0.75Cu7/18Fe7/18Mn1/9Ni1/9O2: 0.77756, Na:1:0.75;O:-2:2.0;Cu:2:0.3888888888888889;Fe:1:0.3888888888888889;Mn:3:0.1111111111111111;Ni:4:0.1111111111111111;FinalChargeBalance:-1.30556
# Discrepancy found for Na0.75Mn7/18Ni7/18Fe1/9Cu1/9O2: 0.49999, Na:1:0.75;O:-2:2.0;Cu:1:0.1111111111111111;Fe:1:0.1111111111111111;Mn:3:0.3888888888888889;Ni:2:0.09722;Ni:4:0.29167;FinalChargeBalance:-0.49999
# Discrepancy found for Na0.75Cu7/18Mn7/18Fe1/9Ni1/9O2: 0.22121, Na:1:0.75;O:-2:2.0;Cu:2:0.3888888888888889;Fe:1:0.1111111111111111;Ni:4:0.1111111111111111;Mn:4:0.34259;Mn:7:0.0463;FinalChargeBalance:-0.22221
# Discrepancy found for Na0.5Mn2/3Cu1/6Fe1/6O2: 0.66666, Na:1:0.5;O:-2:2.0;Cu:2:0.16666666666666666;Mn:3:0.6666666666666666;Fe:3:0.16667;FinalChargeBalance:-0.66666
# Discrepancy found for Na0.5Mn2/3Ni1/6Cu1/6O2: 0.66665, Na:1:0.5;O:-2:2.0;Cu:1:0.16666666666666666;Mn:3:0.6666666666666666;Ni:4:0.16667;FinalChargeBalance:-0.66665
# Discrepancy found for Na0.5Mn2/3Fe1/6Ni1/6O2: 0.83331, Na:1:0.5;O:-2:2.0;Fe:1:0.16666666666666666;Mn:3:0.6666666666666666;Ni:2:0.08333;Ni:4:0.08334;FinalChargeBalance:-0.83331
# Discrepancy found for Na0.5Fe2/3Cu1/6Mn1/6O2: 1.3343099999999999, Na:1:0.5;O:-2:2.0;Cu:2:0.16666666666666666;Fe:1:0.6666666666666666;Mn:7:0.16667;FinalChargeBalance:-1.33331
# Discrepancy found for Na0.5Fe2/3Cu1/6Ni1/6O2: 1.3363299999999998, Na:1:0.5;O:-2:2.0;Cu:2:0.16666666666666666;Fe:1:0.6666666666666666;Ni:4:0.16666666666666666;FinalChargeBalance:-1.83333
# Discrepancy found for Na0.5Ni2/3Cu1/6Mn1/6O2: 0.16665, Na:1:0.5;O:-2:2.0;Cu:1:0.16666666666666666;Mn:3:0.16666666666666666;Ni:4:0.66667;FinalChargeBalance:-0.16665
# Discrepancy found for Na0.5Fe2/3Ni1/6Mn1/6O2: 1.33231, Na:1:0.5;O:-2:2.0;Fe:1:0.6666666666666666;Ni:4:0.16666666666666666;Mn:4:0.11111;Mn:7:0.05556;FinalChargeBalance:-1.33331
# Discrepancy found for Na0.5Cu2/3Fe1/6Ni1/6O2: 0.3363299999999999, Na:1:0.5;O:-2:2.0;Cu:2:0.6666666666666666;Fe:1:0.16666666666666666;Ni:4:0.16666666666666666;FinalChargeBalance:-1.33333
# Discrepancy found for Na0.5Cu2/3Ni1/6Fe1/6O2: 0.3363299999999999, Na:1:0.5;O:-2:2.0;Cu:2:0.6666666666666666;Fe:1:0.16666666666666666;Ni:4:0.16666666666666666;FinalChargeBalance:-1.33333
# Discrepancy found for Na0.5Ni2/3Fe1/6Mn1/6O2: 0.33231, Na:1:0.5;O:-2:2.0;Fe:1:0.16666666666666666;Mn:3:0.16666666666666666;Ni:2:0.08333;Ni:4:0.58334;FinalChargeBalance:-0.33331
# Discrepancy found for Na0.5Cu2/3Ni1/9Mn1/9Fe1/9O2: 0.22177999999999987, Na:1:0.5;O:-2:2.0;Cu:2:0.6666666666666666;Fe:1:0.1111111111111111;Mn:3:0.1111111111111111;Ni:4:0.1111111111111111;FinalChargeBalance:-1.27778
# Discrepancy found for Na0.5Fe2/3Cu1/9Mn1/9Ni1/9O2: 1.33333, Na:1:0.5;O:-2:2.0;Cu:2:0.1111111111111111;Fe:1:0.6666666666666666;Mn:3:0.1111111111111111;Ni:4:0.1111111111111111;FinalChargeBalance:-1.83333
# Discrepancy found for Na0.5Ni2/3Fe1/9Cu1/9Mn1/9O2: 0.22222, Na:1:0.5;O:-2:2.0;Fe:1:0.1111111111111111;Mn:3:0.1111111111111111;Ni:4:0.6666666666666666;Cu:1:0.05555;Cu:2:0.05556;FinalChargeBalance:-0.22222
# Discrepancy found for Na0.5Mn2/3Cu1/9Fe1/9Ni1/9O2: 0.77777, Na:1:0.5;O:-2:2.0;Fe:1:0.1111111111111111;Mn:3:0.6666666666666666;Ni:4:0.1111111111111111;Cu:1:0.05555;Cu:2:0.05556;FinalChargeBalance:-0.77777
# Discrepancy found for Na0.5Mn1/9Cu8/27Fe8/27Ni8/27O2: 1.03359, Na:1:0.5;O:-2:2.0;Cu:2:0.2962962962962963;Fe:1:0.2962962962962963;Mn:3:0.1111111111111111;Ni:4:0.2962962962962963;FinalChargeBalance:-1.09259
# Discrepancy found for Na0.5Ni1/9Cu8/27Fe8/27Mn8/27O2: 0.59358, Na:1:0.5;O:-2:2.0;Cu:2:0.2962962962962963;Fe:1:0.2962962962962963;Ni:4:0.1111111111111111;Mn:4:0.16667;Mn:7:0.12963;FinalChargeBalance:-0.59258
# Discrepancy found for Na0.5Fe1/9Mn8/27Cu8/27Ni8/27O2: 0.22221, Na:1:0.5;O:-2:2.0;Cu:2:0.2962962962962963;Fe:1:0.1111111111111111;Ni:4:0.2962962962962963;Mn:4:0.2284;Mn:7:0.0679;FinalChargeBalance:-0.22221
# Discrepancy found for Na0.5Cu1/9Mn8/27Fe8/27Ni8/27O2: 0.59156, Na:1:0.5;O:-2:2.0;Cu:2:0.1111111111111111;Fe:1:0.2962962962962963;Ni:4:0.2962962962962963;Mn:4:0.29012;Mn:7:0.00618;FinalChargeBalance:-0.59256
# Discrepancy found for Na0.5Fe7/18Ni7/18Cu1/9Mn1/9O2: 0.77777, Na:1:0.5;O:-2:2.0;Cu:2:0.1111111111111111;Fe:1:0.3888888888888889;Ni:4:0.3888888888888889;Mn:4:0.07407;Mn:7:0.03704;FinalChargeBalance:-0.77777
# Discrepancy found for Na0.5Cu7/18Ni7/18Fe1/9Mn1/9O2: 0.22221999999999997, Na:1:0.5;O:-2:2.0;Cu:2:0.3888888888888889;Fe:1:0.1111111111111111;Mn:3:0.1111111111111111;Ni:4:0.3888888888888889;FinalChargeBalance:-0.72222
# Discrepancy found for Na0.5Fe7/18Mn7/18Cu1/9Ni1/9O2: 0.77776, Na:1:0.5;O:-2:2.0;Cu:2:0.1111111111111111;Fe:1:0.3888888888888889;Ni:4:0.1111111111111111;Mn:4:0.35185;Mn:7:0.03704;FinalChargeBalance:-0.77776
# Discrepancy found for Na0.5Cu7/18Fe7/18Mn1/9Ni1/9O2: 0.77756, Na:1:0.5;O:-2:2.0;Cu:2:0.3888888888888889;Fe:1:0.3888888888888889;Mn:3:0.1111111111111111;Ni:4:0.1111111111111111;FinalChargeBalance:-1.55556
# Discrepancy found for Na0.5Mn7/18Ni7/18Fe1/9Cu1/9O2: 0.5, Na:1:0.5;O:-2:2.0;Fe:1:0.1111111111111111;Mn:3:0.3888888888888889;Ni:4:0.3888888888888889;Cu:1:0.05555;Cu:2:0.05556;FinalChargeBalance:-0.5
# Discrepancy found for Na0.5Cu7/18Mn7/18Fe1/9Ni1/9O2: 0.22322, Na:1:0.5;O:-2:2.0;Cu:2:0.3888888888888889;Fe:1:0.1111111111111111;Ni:4:0.1111111111111111;Mn:4:0.25926;Mn:7:0.12963;FinalChargeBalance:-0.22222
