# %%
from cleaningup_plottingcode import *

# %%
analyzer = ApprOXimate()

# %%
formula_string = "Na1.2Mn0.5V0.5O2"

plot_avg_oxidation_states(analyzer, formula=formula_string, alkali_metal='Na', interval=0.015, max_range=2.0, 
                             colormap='inferno', cmap_range=(0.2, 0.8))

plot_individual_oxidation_states(analyzer, formula=formula_string, 
                                     alkali_metal='Na', interval=0.01, max_range=1.2, 
                                     colormap='inferno', cmap_range=(0.1, 0.9))

# %%
plot_individual_oxidation_states(analyzer, formula="LiMnO1.5", 
                                     alkali_metal='Li', interval=0.01, max_range=2.0, 
                                     colormap='inferno', cmap_range=(0.1, 0.9))

# %%
# plt.rcParams["figure.facecolor"] = "#fafafa"
# plt.rcParams["axes.facecolor"] = "#fafafa"

# %%
# Create a figure with 2 panels side by side
fig, axes = create_multi_panel_figure(nrows=1, ncols=2, figsize=(15, 6))

# Panel (a) - Simple charge balance
plot_charge_balance_simple_ax(
    axes[0], 
    analyzer, 
    formula='NaCo0.5Fe0.5O2', 
    alkali_metal='Na', 
    interval=0.01, 
    max_range=2.0
)
# add_panel_label(axes[0], '(a)')

# Panel (b) - Substitution charge balance
plot_charge_balance_substitution_ax(
    axes[1],
    analyzer,
    base_formula="NaCoO2",
    metal_A="Co",
    metal_B="Fe",
    fractions=np.linspace(0.1, 0.9, 9),
    cmap_name="inferno"
)
# add_panel_label(axes[1], '(b)')

plt.tight_layout()
plt.savefig('combined_charge_balance.png', dpi=600)  # Save the figure
plt.show()
# Out:
# C:\Users\fayat\AppData\Local\Temp\ipykernel_3856\3674310426.py:27: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Create a figure with 2 panels side by side
fig, axes = create_multi_panel_figure(nrows=1, ncols=2, figsize=(15, 6))

# Panel (a) - Average oxidation states
plot_avg_oxidation_states_ax(
    axes[0],
    analyzer, 
    formula='NaCo0.7Ni0.2Mn0.1O2', 
    alkali_metal='Na', 
    interval=0.015, 
    max_range=2.0, 
    colormap='inferno', 
    cmap_range=(0.2, 0.8)
)
# add_panel_label(axes[0], '(a)')

# Panel (b) - Individual oxidation states
plot_individual_oxidation_states_ax(
    axes[1],
    analyzer, 
    formula='NaCo0.7Ni0.2Mn0.1O2', 
    alkali_metal='Na', 
    interval=0.015, 
    max_range=1.0, 
    colormap='inferno', 
    cmap_range=(0.1, 0.9)
)
# add_panel_label(axes[1], '(b)')

plt.tight_layout()
plt.savefig('oxidation_states_combined.png', dpi=600)
plt.show()
# Out:
# C:\Users\fayat\AppData\Local\Temp\ipykernel_3856\3656054630.py:30: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Create a figure with 2 panels side by side
fig, axes = create_multi_panel_figure(
    nrows=2,
    ncols=2,
    figsize=(15, 13),
    hspace=0.2,   # smaller vertical spacing
    wspace=0.2    # smaller horizontal spacing
)

# Panel (a) - Simple charge balance
plot_charge_balance_simple_ax(
    axes[0,0], 
    analyzer, 
    formula='NaCo0.5Fe0.5O2', 
    alkali_metal='Na', 
    interval=0.01, 
    max_range=2.0
)
add_panel_label(axes[0,0], '(a)', fontweight="normal")

# Panel (b) - Substitution charge balance
plot_charge_balance_substitution_ax(
    axes[0,1],
    analyzer,
    base_formula="NaCoO2",
    metal_A="Co",
    metal_B="Fe",
    fractions=np.linspace(0.1, 0.9, 9),
    cmap_name="inferno"
)
add_panel_label(axes[0,1], '(b)', fontweight="normal")

# Panel (c) - Average oxidation states
plot_avg_oxidation_states_ax(
    axes[1,0],
    analyzer, 
    formula='NaCo0.7Ni0.2Mn0.1O2', 
    alkali_metal='Na', 
    interval=0.015, 
    max_range=2.0, 
    colormap='inferno', 
    cmap_range=(0.2, 0.8)
)
add_panel_label(axes[1,0], '(c)', fontweight="normal")

# Panel (d) - Individual oxidation states
plot_individual_oxidation_states_ax(
    axes[1,1],
    analyzer, 
    formula='NaCo0.7Ni0.2Mn0.1O2', 
    alkali_metal='Na', 
    interval=0.015, 
    max_range=1.0, 
    colormap='inferno', 
    cmap_range=(0.1, 0.9)
)
add_panel_label(axes[1,1], '(d)', fontweight="normal")

# plt.tight_layout()
plt.savefig('figure3_all.png', dpi=800)
plt.show()

# %%
# Create a figure with 2 panels side by side
fig, axes = create_multi_panel_figure(nrows=1, ncols=2, figsize=(15, 6))

# Panel (a) - Simple charge balance
plot_charge_balance_substitution_ax(
    axes[0],
    analyzer,
    base_formula="NaCo0.7Ni0.2Mn0.1O2",
    metal_A="Co",
    metal_B="Fe",
    fractions=np.linspace(0.1, 0.9, 9),
    cmap_name="inferno"
)
# add_panel_label(axes[0], '(a)')

# Panel (b) - Substitution charge balance
plot_individual_oxidation_states_ax(
    axes[1],
    analyzer, 
    formula='NaCo0.5Fe0.5O2', 
    alkali_metal='Na', 
    interval=0.015, 
    max_range=1.0, 
    colormap='inferno', 
    cmap_range=(0.1, 0.9)
)
# add_panel_label(axes[1], '(b)')

plt.tight_layout()
plt.savefig('combined_charge_balance.png', dpi=600)  # Save the figure
plt.show()
# Out:
# C:\Users\fayat\AppData\Local\Temp\ipykernel_3856\2814816078.py:29: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
filename = "../approx/Data/variable_ox_states_srps.csv"

import pandas as pd

df = pd.read_csv(filename)

data = df['SRP (V)'].to_numpy()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define custom bin edges
bins = np.arange(-3, 2.2, 0.2)

# Create the histogram
plt.figure(figsize=(8, 6))
plt.hist(data, bins=bins, color="#e55c30", edgecolor="white")

# X-axis ticks at bin centers with interval labels
bin_centers = (bins[:-1] + bins[1:]) / 2
labels = [f"({bins[i]:.2f}, {bins[i+1]:.2f}]" for i in range(len(bins) - 1)]

plt.xticks(bin_centers, labels, rotation=60, ha="right")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
element_block = {
    # s-block
    "H": "s", "He": "s", "Li": "s", "Be": "s",
    "Na": "s", "Mg": "s", "K": "s", "Ca": "s",

    # p-block
    "B": "p", "C": "p", "N": "p", "O": "p", "F": "p", "Ne": "p",
    "Al": "p", "Si": "p", "P": "p", "S": "p", "Cl": "p", "Ar": "p",
    "Ge": "p", "As": "p", "Se": "p", "Sn": "p", "Sb": "p", "Te": "p",
    "Pb": "p", "Bi": "p",

    # d-block
    "Sc": "d", "Ti": "d", "V": "d", "Cr": "d", "Mn": "d", "Fe": "d",
    "Co": "d", "Ni": "d", "Cu": "d", "Zn": "d",
    "Nb": "d", "Mo": "d", "Tc": "d", "Ru": "d", "Rh": "d",
    "Pd": "d", "Ag": "d", "Cd": "d", "Ta": "d", "W": "d",
    "Re": "d", "Os": "d", "Ir": "d", "Pt": "d", "Au": "d",

    # f-block
    "Ce": "f", "Pr": "f", "Nd": "f", "Pm": "f", "Sm": "f", "Eu": "f",
    "Gd": "f", "Tb": "f", "Dy": "f", "Ho": "f", "Er": "f",
    "Tm": "f", "Yb": "f", "Lu": "f",
    "U": "f", "Np": "f", "Pu": "f", "Am": "f", "Cm": "f",
    "Bk": "f", "Cf": "f", "Es": "f", "Fm": "f", "Md": "f", "No": "f"
}

# %%
filename = "../approx/Data/variable_ox_states_srps.csv"

import pandas as pd

df = pd.read_csv(filename)
df["Block"] = df["Element"].map(element_block)

# %%
get_colormap_colors(3,'inferno')
# Out:
# [(np.float64(0.087411),
#   np.float64(0.044556),
#   np.float64(0.224813),
#   np.float64(1.0)),
#  (np.float64(0.735683),
#   np.float64(0.215906),
#   np.float64(0.330245),
#   np.float64(1.0)),
#  (np.float64(0.964394),
#   np.float64(0.843848),
#   np.float64(0.273391),
#   np.float64(1.0))]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# 1. Setup Bins (27 total buckets)
bins = np.arange(-3, 2.25, 0.25)
df["bin_idx"] = np.digitize(df["SRP (V)"], bins, right=True)

# 2. Create a Cross-Tabulation (Counts of each Block per Bin)
# This creates a table where rows are bins and columns are s, p, d, f
composition = pd.crosstab(df["bin_idx"], df["Block"])

# Ensure all bins (0-26) and all blocks are represented, even if empty
all_indices = range(len(bins) + 1)
all_blocks = ["p", "d", "f"]
composition = composition.reindex(index=all_indices, columns=all_blocks, fill_value=0)

# 3. Plotting
plt.figure(figsize=(8, 6))
block_colors = {
    "p": "#57106e",  # Dark Purple
    "d": "#e55c30",  # Rust Red/Orange
    "f": "#fbbe23"   # Bright Yellow
}
bottoms = np.zeros(len(all_indices))

block_hatches = {"p": "//", "d": "..", "f": "xx"}

for block in all_blocks:
    plt.bar(
        all_indices, 
        composition[block], 
        bottom=bottoms, 
        color=block_colors[block],
        hatch=block_hatches[block],  # Apply the pattern here
        edgecolor="white",           # White edges help patterns pop
        linewidth=0.5,
        width=0.85, 
        label=f"{block}-block"
    )
    bottoms += composition[block]
    
labels = ["< -3"] + \
         [f"({bins[i]:.2f}, {bins[i+1]:.2f}]" for i in range(len(bins)-1)] + \
         ["> 2"]

plt.xticks(range(len(labels)), labels, rotation=90, ha="right")
plt.ylabel("Frequency")
plt.legend(title="Periodic Table Block", frameon=False)
plt.tight_layout()
plt.show()
