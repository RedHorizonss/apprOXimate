# %%
from approx.approximate import ApprOXimate
from approx.feature_engineering import MaterialFeatureExtractor
from mendeleev.fetch import fetch_table

# %%
import pandas as pd

df = pd.read_csv('Crystal_structure.csv')

df
# Out:
#      Compound   A   B  In literature v(A) v(B)  r(AXII)(Å)  r(AVI)(Å)  \
# 0       Ac2O3  Ac  Ac          False    0    0        1.12       1.12
# 1      AcAgO3  Ac  Ag          False    0    0        1.12       1.12
# 2      AcAlO3  Ac  Al          False    0    0        1.12       1.12
# 3      AcAsO3  Ac  As          False    0    0        1.12       1.12
# 4      AcAuO3  Ac  Au          False    0    0        1.12       1.12
# ...       ...  ..  ..            ...  ...  ...         ...        ...
# 5324    ZrWO3  Zr   W          False    1    5        0.89       0.72
# 5325    ZrYO3  Zr   Y          False    -    -        0.89       0.72
# 5326   ZrYbO3  Zr  Yb          False    -    -        0.89       0.72
# 5327   ZrZnO3  Zr  Zn          False    -    -        0.89       0.72
# 5328    Zr2O3  Zr  Zr          False    -    -        0.89       0.72
#
#       r(BVI)(Å)  EN(A)  EN(B)  l(A-O)(Å)  l(B-O)(Å)      ΔENR        tG  \
# 0          1.12   1.10   1.10    0.00000   0.000000 -3.248000  0.707107
# 1          0.95   1.10   1.93    0.00000   2.488353 -2.565071  0.758259
# 2          0.54   1.10   1.61    0.00000   1.892894 -1.846714  0.918510
# 3          0.52   1.10   2.18    0.00000   1.932227 -1.577429  0.928078
# 4          0.93   1.10   2.54    0.00000   2.313698 -2.279786  0.764768
# ...         ...    ...    ...        ...        ...       ...       ...
# 5324       0.62   1.33   2.36    2.38342   1.745600 -1.572214  0.801621
# 5325       0.90   1.33   1.22    2.38342   2.235124 -2.489571  0.704032
# 5326       0.95   1.33   1.10    2.38342   2.223981 -2.626821  0.689053
# 5327       0.74   1.33   1.65    2.38342   2.096141 -2.035750  0.756670
# 5328       0.72   1.33   1.33    2.38342   2.043778 -2.097821  0.763809
#
#                 τ         μ Lowest distortion
# 0               -  0.800000             cubic
# 1               -  0.678571      orthorhombic
# 2               -  0.385714             cubic
# 3               -  0.371429      orthorhombic
# 4               -  0.664286      orthorhombic
# ...           ...       ...               ...
# 5324  5.228952455  0.442857             cubic
# 5325            -  0.642857             cubic
# 5326            -  0.678571      orthorhombic
# 5327            -  0.528571             cubic
# 5328            -  0.514286             cubic
#
# [5329 rows x 18 columns]

# %% [markdown]
# # Data Cleaning

# %%
df = df[['Compound', 'Lowest distortion']]
df
# Out:
#      Compound Lowest distortion
# 0       Ac2O3             cubic
# 1      AcAgO3      orthorhombic
# 2      AcAlO3             cubic
# 3      AcAsO3      orthorhombic
# 4      AcAuO3      orthorhombic
# ...       ...               ...
# 5324    ZrWO3             cubic
# 5325    ZrYO3             cubic
# 5326   ZrYbO3      orthorhombic
# 5327   ZrZnO3             cubic
# 5328    Zr2O3             cubic
#
# [5329 rows x 2 columns]

# %% [markdown]
# # Feature Engineering

# %%
# approx = ApprOXimate()
# ptable = fetch_table("elements")

# extractor = MaterialFeatureExtractor(approx, ptable, mode="both")
# extractor.get_features("Li2MnO3")

# %%
from tqdm import tqdm

def featurize_df(df, extractor, formula_col="Compound"):
    feature_rows = []

    for f in tqdm(df[formula_col], desc="Feat compounds"):
        feats = extractor.get_features(f)
        feature_rows.append(feats)

    feat_df = pd.DataFrame(feature_rows)
    return df.join(feat_df)


# Initialize modules
approx = ApprOXimate()
ptable = fetch_table("elements")
extractor = MaterialFeatureExtractor(approx, ptable, mode="all")

# Run featurization
df_feat = featurize_df(df, extractor)
df_feat.head()
# Out:
# Feat compounds:   2%|▏         | 80/5329 [00:58<1:04:21,  1.36it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 20
#      17 extractor = MaterialFeatureExtractor(approx, ptable, mode="all")
#      19 # Run featurization
# ---> 20 df_feat = featurize_df(df, extractor)
#      21 df_feat.head()
#
# Cell In[9], line 7, in featurize_df(df, extractor, formula_col)
#       4 feature_rows = []
#       6 for f in tqdm(df[formula_col], desc="Feat compounds"):
# ----> 7     feats = extractor.get_features(f)
#       8     feature_rows.append(feats)
#      10 feat_df = pd.DataFrame(feature_rows)
#
# File c:\Users\fayat\Documents\apprOXimate\approx\feature_engineering\feature_extractor.py:67, in MaterialFeatureExtractor.get_features(self, formula)
#      64 features = {"formula": formula}
#      66 for module in self.modules:
# ---> 67     mod_feats = module.get_features(formula)
#      69     # Filter feature names based on mode
#      70     mod_feats = module.filter_mode(mod_feats, self.mode)
#
# File c:\Users\fayat\Documents\apprOXimate\approx\feature_engineering\valence_features.py:74, in get_features(self, formula)
#      67 for channel in ["s", "p", "d", "f", "total"]:
#      68     out |= StatsExpander.expand(
#      69         [vals[channel] for vals in filled_values],
#      70         weights,
#      71         prefix=f"{prefix}valence_{channel}_"
#      72     )
# ---> 74     out |= StatsExpander.expand(
#      75         [vals[channel] for vals in unfilled_values],
#      76         weights,
#      77         prefix=f"{prefix}unfilled_valence_{channel}_"
#      78     )
#      80 return out
#
# File c:\Users\fayat\Documents\apprOXimate\approx\feature_engineering\valence_features.py:42, in _expand_group(self, elems, prefix)
#      40 else:
#      41     occupancy = self._orbital_occupancy(config, period)
# ---> 42     occupancy = self._fill_anion_valence(occupancy, abs(int(ox)))
#      44 return occupancy | {"total": sum(occupancy.values())}
#
# File c:\Users\fayat\Documents\apprOXimate\approx\feature_engineering\valence_features.py:12, in get_valence(self, element, ox)
#       7 @staticmethod
#       8 def _orbital_occupancy(config, period):
#       9     return {
#      10         "s": config.conf.get((period, "s"), 0),
#      11         "p": config.conf.get((period, "p"), 0),
# ---> 12         "d": config.conf.get((period - 1, "d"), 0),
#      13         "f": config.conf.get((period - 1, "f"), 0),
#      14     }
#
# File c:\Users\fayat\Documents\apprOXimate\.venv\Lib\site-packages\pandas\core\frame.py:4826, in DataFrame.query(self, expr, inplace, **kwargs)
#    4823 res = self.eval(expr, **kwargs)
#    4825 try:
# -> 4826     result = self.loc[res]
#    4827 except ValueError:
#    4828     # when res is multi-dimensional loc raises, but this is sometimes a
#    4829     # valid query
#    4830     result = self[res]
#
# File c:\Users\fayat\Documents\apprOXimate\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\fayat\Documents\apprOXimate\.venv\Lib\site-packages\pandas\core\indexing.py:1413, in _LocIndexer._getitem_axis(self, key, axis)
#    1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
# -> 1413     return self._getbool_axis(key, axis=axis)
#    1414 elif is_list_like_indexer(key):
#    1415     # an iterable multi-selection
#    1416     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File c:\Users\fayat\Documents\apprOXimate\.venv\Lib\site-packages\pandas\core\indexing.py:1209, in _LocationIndexer._getbool_axis(self, key, axis)
#    1205 @final
#    1206 def _getbool_axis(self, key, axis: AxisInt):
#    1207     # caller is responsible for ensuring non-None axis
#    1208     labels = self.obj._get_axis(axis)
# -> 1209     key = check_bool_indexer(labels, key)
#    1210     inds = key.nonzero()[0]
#    1211     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File c:\Users\fayat\Documents\apprOXimate\.venv\Lib\site-packages\pandas\core\indexing.py:2681, in check_bool_indexer(index, key)
#    2677 elif not is_array_like(result):
#    2678     # GH 33924
#    2679     # key may contain nan elements, check_array_indexer needs bool array
#    2680     result = pd_array(result, dtype=bool)
# -> 2681 return check_array_indexer(index, result)
#
# File c:\Users\fayat\Documents\apprOXimate\.venv\Lib\site-packages\pandas\core\indexers\utils.py:517, in check_array_indexer(array, indexer)
#     511 from pandas.core.construction import array as pd_array
#     513 # whatever is not an array-like is returned as-is (possible valid array
#     514 # indexers that are not array-like: integer, slice, Ellipsis, None)
#     515 # In this context, tuples are not considered as array-like, as they have
#     516 # a specific meaning in indexing (multi-dimensional indexing)
# --> 517 if is_list_like(indexer):
#     518     if isinstance(indexer, tuple):
#     519         return indexer
#
# File lib.pyx:1241, in pandas._libs.lib.is_list_like()
#
# File lib.pyx:1259, in pandas._libs.lib.c_is_list_like()
#
# File c:\Users\fayat\Documents\apprOXimate\.venv\Lib\site-packages\pandas\core\base.py:363, in IndexOpsMixin.ndim(self)
#     359 def __len__(self) -> int:
#     360     # We need this defined here for mypy
#     361     raise AbstractMethodError(self)
# --> 363 @property
#     364 def ndim(self) -> Literal[1]:
#     365     """
#     366     Number of dimensions of the underlying data, by definition 1.
#     367
#    (...)    385     1
#     386     """
#     387     return 1
#
# KeyboardInterrupt:

# %%
df_feat.to_csv('featurised_data.csv', index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
